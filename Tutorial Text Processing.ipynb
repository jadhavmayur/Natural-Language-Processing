# %% [markdown]
# ## Text Processing
#
# ### Capturing Text Data
# #### Plain Text

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Read in a plain text file
with open(os.path.join("/content/drive/MyDrive/NLP/data ", "hieroglyph.txt"), "r") as f:
  text=f.read()
  print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %% [markdown]
# #### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df=pd.read_csv("/content/drive/MyDrive/NLP/data /news.csv")


# Convert text column to lowercase
df['title']=df['title'].str.lower()
df.head()[['publisher','title']]
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace

# %% [markdown]
# #### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r=requests.get("https://quotes.rest/qod.json")
res=r.json()
print(json.dumps(res,indent=4))
# Out:
# {
#     "success": {
#         "total": 1
#     },
#     "contents": {
#         "quotes": [
#             {
#                 "quote": "Not every day is going to offer us a chance to save somebody's life, but every day offers us an opportunity to affect one.",
#                 "length": "122",
#                 "author": "Mark Bezos",
#                 "tags": {
#                     "0": "inspire",
#                     "1": "life",
#                     "3": "tod"
#                 },
#                 "category": "inspire",
#                 "language": "en",
#                 "date": "2022-05-19",
#                 "permalink": "https://theysaidso.com/quote/mark-bezos-not-every-day-is-going-to-offer-us-a-chance-to-save-somebodys-life-bu",
#                 "id": "9V2lXZnG7op9S4S8prwXfQeF",
#                 "background": "https://theysaidso.com/img/qod/qod-inspire.jpg",
#                 "title": "Inspiring Quote of the day"
#             }
#         ]
#     },
#     "baseurl": "https://theysaidso.com",
#     "copyright": {
#         "year": 2024,
#         "url": "https://theysaidso.com"
#     }
# }

# %%
# Extract relevant object and field
q=res['contents']['quotes'][0]
print(q["quote"], "\n--", q["author"])
# Out:
# Not every day is going to offer us a chance to save somebody's life, but every day offers us an opportunity to affect one.
# -- Mark Bezos

# %% [markdown]
# #### Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://news.ycombinator.com")
print(r.text)
# Out:
# <html lang="en" op="news"><head><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width, initial-scale=1.0"><link rel="stylesheet" type="text/css" href="news.css?F2tdhQa6ArfaD03Cf9Jc">
#         <link rel="shortcut icon" href="favicon.ico">
#           <link rel="alternate" type="application/rss+xml" title="RSS" href="rss">
#         <title>Hacker News</title></head><body><center><table id="hnmain" border="0" cellpadding="0" cellspacing="0" width="85%" bgcolor="#f6f6ef">
#         <tr><td bgcolor="#ff6600"><table border="0" cellpadding="0" cellspacing="0" width="100%" style="padding:2px"><tr><td style="width:18px;padding-right:4px"><a href="https://news.ycombinator.com"><img src="y18.gif" width="18" height="18" style="border:1px white solid;"></a></td>
#                   <td style="line-height:12pt; height:10px;"><span class="pagetop"><b class="hnname"><a href="news">Hacker News</a></b>
#               <a href="newest">new</a> | <a href="front">past</a> | <a href="newcomments">comments</a> | <a href="ask">ask</a> | <a href="show">show</a> | <a href="jobs">jobs</a> | <a href="submit">submit</a>            </span></td><td style="text-align:right;padding-right:4px;"><span class="pagetop">
#                               <a href="login?goto=news">login</a>
#                           </span></td>
#               </tr></table></td></tr>
# <tr id="pagespace" title="" style="height:10px"></tr><tr><td><table border="0" cellpadding="0" cellspacing="0" class="itemlist">
#               <tr class='athing' id='31432573'>
#       <td align="right" valign="top" class="title"><span class="rank">1.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31432573'href='vote?id=31432573&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.visiticeland.com/outhorse-your-email/" class="titlelink">Outhorse Your Email</a><span class="sitebit comhead"> (<a href="from?site=visiticeland.com"><span class="sitestr">visiticeland.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31432573">221 points</span> by <a href="user?id=eorri" class="hnuser">eorri</a> <span class="age" title="2022-05-19T09:52:27"><a href="item?id=31432573">2 hours ago</a></span> <span id="unv_31432573"></span> | <a href="hide?id=31432573&amp;goto=news">hide</a> | <a href="item?id=31432573">40&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31426683'>
#       <td align="right" valign="top" class="title"><span class="rank">2.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31426683'href='vote?id=31426683&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://tarunreddy.bearblog.dev/addict/" class="titlelink">I'm an addict</a><span class="sitebit comhead"> (<a href="from?site=bearblog.dev"><span class="sitestr">bearblog.dev</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31426683">71 points</span> by <a href="user?id=tarunreddy" class="hnuser">tarunreddy</a> <span class="age" title="2022-05-18T19:31:44"><a href="item?id=31426683">2 hours ago</a></span> <span id="unv_31426683"></span> | <a href="hide?id=31426683&amp;goto=news">hide</a> | <a href="item?id=31426683">23&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31432648'>
#       <td align="right" valign="top" class="title"><span class="rank">3.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31432648'href='vote?id=31432648&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://nautil.us/you-eat-a-credits-card-worth-of-plastic-every-week-17950/" class="titlelink">You Eat a Credit’s Card Worth of Plastic Every Week</a><span class="sitebit comhead"> (<a href="from?site=nautil.us"><span class="sitestr">nautil.us</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31432648">54 points</span> by <a href="user?id=dnetesn" class="hnuser">dnetesn</a> <span class="age" title="2022-05-19T10:08:52"><a href="item?id=31432648">1 hour ago</a></span> <span id="unv_31432648"></span> | <a href="hide?id=31432648&amp;goto=news">hide</a> | <a href="item?id=31432648">41&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31431287'>
#       <td align="right" valign="top" class="title"><span class="rank">4.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31431287'href='vote?id=31431287&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://libera.chat/news/happy-birthday-libera-chat" class="titlelink">Happy Birthday, Libera Chat</a><span class="sitebit comhead"> (<a href="from?site=libera.chat"><span class="sitestr">libera.chat</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31431287">188 points</span> by <a href="user?id=mcwhy" class="hnuser">mcwhy</a> <span class="age" title="2022-05-19T06:07:13"><a href="item?id=31431287">5 hours ago</a></span> <span id="unv_31431287"></span> | <a href="hide?id=31431287&amp;goto=news">hide</a> | <a href="item?id=31431287">96&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31432936'>
#       <td align="right" valign="top" class="title"><span class="rank">5.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31432936'href='vote?id=31432936&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="item?id=31432936" class="titlelink">Poll: Self Hosting Git Repositories</a></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_
org</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31395921">22 points</span> by <a href="user?id=nkurz" class="hnuser">nkurz</a> <span class="age" title="2022-05-16T11:58:44"><a href="item?id=31395921">5 hours ago</a></span> <span id="unv_31395921"></span> | <a href="hide?id=31395921&amp;goto=news">hide</a> | <a href="item?id=31395921">15&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31432495'>
#       <td align="right" valign="top" class="title"><span class="rank">17.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31432495'href='vote?id=31432495&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://github.com/zalando-incubator/graphql-jit" class="titlelink">GraphQL JIT – GraphQL execution using a JIT compiler</a><span class="sitebit comhead"> (<a href="from?site=github.com/zalando-incubator"><span class="sitestr">github.com/zalando-incubator</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31432495">12 points</span> by <a href="user?id=cheeseface" class="hnuser">cheeseface</a> <span class="age" title="2022-05-19T09:37:51"><a href="item?id=31432495">2 hours ago</a></span> <span id="unv_31432495"></span> | <a href="hide?id=31432495&amp;goto=news">hide</a> | <a href="item?id=31432495">discuss</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31416896'>
#       <td align="right" valign="top" class="title"><span class="rank">18.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31416896'href='vote?id=31416896&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://vladimir.varank.in/notes/2022/05/a-real-life-use-case-for-generics-in-go-api-for-client-side-pagination/" class="titlelink">My real life use-case for generics in Go: API for client-side pagination</a><span class="sitebit comhead"> (<a href="from?site=vladimir.varank.in"><span class="sitestr">vladimir.varank.in</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31416896">18 points</span> by <a href="user?id=varankinv" class="hnuser">varankinv</a> <span class="age" title="2022-05-17T22:11:56"><a href="item?id=31416896">3 hours ago</a></span> <span id="unv_31416896"></span> | <a href="hide?id=31416896&amp;goto=news">hide</a> | <a href="item?id=31416896">9&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31430969'>
#       <td align="right" valign="top" class="title"><span class="rank">19.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31430969'href='vote?id=31430969&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://utcc.utoronto.ca/~cks/space/blog/web/TLSIntermediateCertHell" class="titlelink">Missing TLS intermediate certificates can create mysterious browser problems</a><span class="sitebit comhead"> (<a href="from?site=utoronto.ca"><span class="sitestr">utoronto.ca</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31430969">51 points</span> by <a href="user?id=zdw" class="hnuser">zdw</a> <span class="age" title="2022-05-19T05:00:48"><a href="item?id=31430969">7 hours ago</a></span> <span id="unv_31430969"></span> | <a href="hide?id=31430969&amp;goto=news">hide</a> | <a href="item?id=31430969">28&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31412110'>
#       <td align="right" valign="top" class="title"><span class="rank">20.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31412110'href='vote?id=31412110&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://steveblank.com/2022/05/17/artificial-intelligence-and-machine-learning-explained/" class="titlelink">AI and Machine Learning – The Basics</a><span class="sitebit comhead"> (<a href="from?site=steveblank.com"><span class="sitestr">steveblank.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31412110">144 points</span> by <a href="user?id=sblank" class="hnuser">sblank</a> <span class="age" title="2022-05-17T15:26:46"><a href="item?id=31412110">12 hours ago</a></span> <span id="unv_31412110"></span> | <a href="hide?id=31412110&amp;goto=news">hide</a> | <a href="item?id=31412110">34&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31432908'>
#       <td align="right" valign="top" class="title"><span class="rank">21.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31432908'href='vote?id=31432908&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.bunniestudios.com/blog/?p=6375" class="titlelink" rel="nofollow">Rust: A Critical Retrospective</a><span class="sitebit comhead"> (<a href="from?site=bunniestudios.com"><span class="sitestr">bunniestudios.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_
nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31413919'>
#       <td align="right" valign="top" class="title"><span class="rank">27.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31413919'href='vote?id=31413919&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://johannes.truschnigg.info/writing/2022-05_android_bootloop_debugging/" class="titlelink">Steps towards debugging and resolving Android bootloops</a><span class="sitebit comhead"> (<a href="from?site=truschnigg.info"><span class="sitestr">truschnigg.info</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31413919">11 points</span> by <a href="user?id=c0l0" class="hnuser">c0l0</a> <span class="age" title="2022-05-17T17:34:57"><a href="item?id=31413919">3 hours ago</a></span> <span id="unv_31413919"></span> | <a href="hide?id=31413919&amp;goto=news">hide</a> | <a href="item?id=31413919">1&nbsp;comment</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31424450'>
#       <td align="right" valign="top" class="title"><span class="rank">28.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31424450'href='vote?id=31424450&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.getlago.com/blog/why-billing-systems-are-a-nightmare-for-engineers" class="titlelink">Billing systems are a nightmare for engineers</a><span class="sitebit comhead"> (<a href="from?site=getlago.com"><span class="sitestr">getlago.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31424450">691 points</span> by <a href="user?id=Rafsark" class="hnuser">Rafsark</a> <span class="age" title="2022-05-18T16:06:44"><a href="item?id=31424450">19 hours ago</a></span> <span id="unv_31424450"></span> | <a href="hide?id=31424450&amp;goto=news">hide</a> | <a href="item?id=31424450">334&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31428708'>
#       <td align="right" valign="top" class="title"><span class="rank">29.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31428708'href='vote?id=31428708&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://addyosmani.com/blog/software-eng-10-years/" class="titlelink">Software Engineering Insights from 10 Years at Google</a><span class="sitebit comhead"> (<a href="from?site=addyosmani.com"><span class="sitestr">addyosmani.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31428708">122 points</span> by <a href="user?id=feross" class="hnuser">feross</a> <span class="age" title="2022-05-18T23:03:57"><a href="item?id=31428708">12 hours ago</a></span> <span id="unv_31428708"></span> | <a href="hide?id=31428708&amp;goto=news">hide</a> | <a href="item?id=31428708">94&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='31431387'>
#       <td align="right" valign="top" class="title"><span class="rank">30.</span></td>      <td valign="top" class="votelinks"><center><a id='up_31431387'href='vote?id=31431387&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://devblogs.microsoft.com/dotnet/announcing-dotnet-7-preview-3/" class="titlelink">.NET 7 introduces Native AOT</a><span class="sitebit comhead"> (<a href="from?site=microsoft.com"><span class="sitestr">microsoft.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_31431387">86 points</span> by <a href="user?id=DeathArrow" class="hnuser">DeathArrow</a> <span class="age" title="2022-05-19T06:31:01"><a href="item?id=31431387">5 hours ago</a></span> <span id="unv_31431387"></span> | <a href="hide?id=31431387&amp;goto=news">hide</a> | <a href="item?id=31431387">60&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#             <tr class="morespace" style="height:10px"></tr><tr><td colspan="2"></td>
#       <td class='title'><a href='news?p=2' class='morelink' rel='next'>More</a></td>    </tr>
#   </table>
# </td></tr>
# <tr><td><img src="s.gif" height="10" width="0"><table width="100%" cellspacing="0" cellpadding="1"><tr><td bgcolor="#ff6600"></td></tr></table><br><center><span class="yclinks"><a href="newsguidelines.html">Guidelines</a>
#         | <a href="newsfaq.html">FAQ</a>
#         | <a href="lists">Lists</a>
#         | <a href="https://github.com/HackerNews/API">API</a>
#         | <a href="security.html">Security</a>
#         | <a href="http://www.ycombinator.com/legal/">Legal</a>
#         | <a href="http://www.ycombinator.com/apply/">Apply to YC</a>
#         | <a href="mailto:hn@ycombinator.com">Contact</a></span><br><br><form method="get" action="//hn.algolia.com/">Search:
#           <input type="text" name="q" value="" size="17" autocorrect="off" spellcheck="false" autocapitalize="off" autocomplete="false"></form>
#             </center></td></tr>
#       </table></center></body><script type='text/javascript' src='hn.js?F2tdhQa6ArfaD03Cf9Jc'></script></html>

# %%
import re
# Remove HTML tags using RegEx
pattern=re.compile('<.*?>') # tags look like <...>
print(pattern.sub(" ",r.text)) # replace them with blank
# Out:
#
#
#
#          Hacker News
#
#                       Hacker News
#                new  |  past  |  comments  |  ask  |  show  |  jobs  |  submit
#                                login
#
#
#
#
#         1.                  Outhorse Your Email   (  visiticeland.com  )
#          221 points  by  eorri    2 hours ago      |  hide  |  40&nbsp;comments
#
#
#         2.                  I'm an addict   (  bearblog.dev  )
#          71 points  by  tarunreddy    2 hours ago      |  hide  |  23&nbsp;comments
#
#
#         3.                  You Eat a Credit’s Card Worth of Plastic Every Week   (  nautil.us  )
#          54 points  by  dnetesn    1 hour ago      |  hide  |  41&nbsp;comments
#
#
#         4.                  Happy Birthday, Libera Chat   (  libera.chat  )
#          188 points  by  mcwhy    5 hours ago      |  hide  |  96&nbsp;comments
#
#
#         5.                  Poll: Self Hosting Git Repositories
#          19 points  by  gmemstr    59 minutes ago      |  hide  |  35&nbsp;comments
#
#
#         6.            Aptible (YC S14) is hiring for our secure, compliant PaaS alternative to Heroku   (  aptible.com  )
#           1 minute ago   |  hide
#
#
#         7.                  Attorney General to investigate social media companies’ role in Buffalo attack   (  ny.gov  )
#          15 points  by  giuliomagnifico    55 minutes ago      |  hide  |  13&nbsp;comments
#
#
#         8.                  Duck Chess   (  duckchess.com  )
#          326 points  by  colinprince    10 hours ago      |  hide  |  60&nbsp;comments
#
#
#         9.                  Show HN: HelloInbox – Ultimate email deliverability checklist and toolkit   (  helloinbox.email  )
#          83 points  by  ismaelyws    4 hours ago      |  hide  |  29&nbsp;comments
#
#
#         10.                  FairEmail stopping development after Google falsely flags app as spyware   (  xda-developers.com  )
#          187 points  by  worble    2 hours ago      |  hide  |  56&nbsp;comments
#
#
#         11.                  The Rust Borrow Checker – A Deep Dive   (  infoq.com  )
#          35 points  by  chhhuang    3 hours ago      |  hide  |  26&nbsp;comments
#
#
#         12.                  YC W22 Stablegains is being sued for losing $42m in funds from 4878 customers   (  twitter.com/fatmanterra  )
#          310 points  by  donsupreme    6 hours ago      |  hide  |  201&nbsp;comments
#
#
#         13.                  My thoughts about Fly.io (so far) and other newish technology I'm getting into   (  hartleybrody.com  )
#          69 points  by  hartleybrody    6 hours ago      |  hide  |  52&nbsp;comments
#
#
#         14.                  Show HN: Privaxy – adblocking / tracker blocking by MITMing HTTPS traffic   (  github.com/barre  )
#          7 points  by  pierrebarre    1 hour ago      |  hide  |  discuss
#
#
#         15.                  Korg NTS-2 DIY oscilloscope and wave generator kit   (  korg.com  )
#          94 points  by  dtagames    9 hours ago      |  hide  |  39&nbsp;comments
#
#
#         16.                  The Delicious Origins of the Domesticated Blueberry (2016)   (  jstor.org  )
#          22 points  by  nkurz    5 hours ago      |  hide  |  15&nbsp;comments
#
#
#         17.                  GraphQL JIT – GraphQL execution using a JIT compiler   (  github.com/zalando-incubator  )
#          12 points  by  cheeseface    2 hours ago      |  hide  |  discuss
#
#
#         18.                  My real life use-case for generics in Go: API for client-side pagination   (  vladimir.varank.in  )
#          18 points  by  varankinv    3 hours ago      |  hide  |  9&nbsp;comments
#
#
#         19.                  Missing TLS intermediate certificates can create mysterious browser problems   (  utoronto.ca  )
#          51 points  by  zdw    7 hours ago      |  hide  |  28&nbsp;comments
#
#
#         20.                  AI and Machine Learning – The Basics   (  steveblank.com  )
#          144 points  by  sblank    12 hours ago      |  hide  |  34&nbsp;comments
#
#
#         21.                  Rust: A Critical Retrospective   (  bunniestudios.com  )
#          4 points  by  sohkamyung    1 hour ago      |  hide  |  discuss
#
#
#         22.                  Does communication matter in technical interviews? Here's the data   (  interviewing.io  )
#          50 points  by  leeny    7 hours ago      |  hide  |  26&nbsp;comments
#
#
#         23.                  How to make video calls almost as good as face-to-face (2020)   (  benkuhn.net  )
#          112 points  by  outworlder    13 hours ago      |  hide  |  80&nbsp;comments
#
#
#         24.                  Owl: OCaml Scientific Computing   (  ocaml.xyz  )
#          60 points  by  lnyan    9 hours ago      |  hide  |  10&nbsp;comments
#
#
#         25.                  Apple Is Union-Busting in NYC, Labor Group Alleges   (  bloomberg.com  )
#          17 points  by  carlycue    1 hour ago      |  hide  |  discuss
#
#
#         26.                  Long-Term Building in Japan   (  longnow.org  )
#          109 points  by  tosh    13 hours ago      |  hide  |  89&nbsp;comments
#
#
#         27.                  Steps towards debugging and resolving Android bootloops   (  truschnigg.info  )
#          11 points  by  c0l0    3 hours ago      |  hide  |  1&nbsp;comment
#
#
#         28.                  Billing systems are a nightmare for engineers   (  getlago.com  )
#          691 points  by  Rafsark    19 hours ago      |  hide  |  334&nbsp;comments
#
#
#         29.                  Software Engineering Insights from 10 Years at Google   (  addyosmani.com  )
#          122 points  by  feross    12 hours ago      |  hide  |  94&nbsp;comments
#
#
#         30.                  .NET 7 introduces Native AOT   (  microsoft.com  )
#          86 points  by  DeathArrow    5 hours ago      |  hide  |  60&nbsp;comments
#
#
#         More
#
#
#              Guidelines
#         |  FAQ
#         |  Lists
#         |  API
#         |  Security
#         |  Legal
#         |  Apply to YC
#         |  Contact     Search:

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup=BeautifulSoup(r.text,'html5lib')
print(soup.get_text())
# Out:
#
#
#         Hacker News
#
#                   Hacker News
#               new | past | comments | ask | show | jobs | submit
#                               login
#
#
#
#
#       1.      Outhorse Your Email (visiticeland.com)
#         221 points by eorri 2 hours ago  | hide | 40 comments
#
#
#       2.      I'm an addict (bearblog.dev)
#         71 points by tarunreddy 2 hours ago  | hide | 23 comments
#
#
#       3.      You Eat a Credit’s Card Worth of Plastic Every Week (nautil.us)
#         54 points by dnetesn 1 hour ago  | hide | 41 comments
#
#
#       4.      Happy Birthday, Libera Chat (libera.chat)
#         188 points by mcwhy 5 hours ago  | hide | 96 comments
#
#
#       5.      Poll: Self Hosting Git Repositories
#         19 points by gmemstr 59 minutes ago  | hide | 35 comments
#
#
#       6.      Aptible (YC S14) is hiring for our secure, compliant PaaS alternative to Heroku (aptible.com)
#         1 minute ago | hide
#
#
#       7.      Attorney General to investigate social media companies’ role in Buffalo attack (ny.gov)
#         15 points by giuliomagnifico 55 minutes ago  | hide | 13 comments
#
#
#       8.      Duck Chess (duckchess.com)
#         326 points by colinprince 10 hours ago  | hide | 60 comments
#
#
#       9.      Show HN: HelloInbox – Ultimate email deliverability checklist and toolkit (helloinbox.email)
#         83 points by ismaelyws 4 hours ago  | hide | 29 comments
#
#
#       10.      FairEmail stopping development after Google falsely flags app as spyware (xda-developers.com)
#         187 points by worble 2 hours ago  | hide | 56 comments
#
#
#       11.      The Rust Borrow Checker – A Deep Dive (infoq.com)
#         35 points by chhhuang 3 hours ago  | hide | 26 comments
#
#
#       12.      YC W22 Stablegains is being sued for losing $42m in funds from 4878 customers (twitter.com/fatmanterra)
#         310 points by donsupreme 6 hours ago  | hide | 201 comments
#
#
#       13.      My thoughts about Fly.io (so far) and other newish technology I'm getting into (hartleybrody.com)
#         69 points by hartleybrody 6 hours ago  | hide | 52 comments
#
#
#       14.      Show HN: Privaxy – adblocking / tracker blocking by MITMing HTTPS traffic (github.com/barre)
#         7 points by pierrebarre 1 hour ago  | hide | discuss
#
#
#       15.      Korg NTS-2 DIY oscilloscope and wave generator kit (korg.com)
#         94 points by dtagames 9 hours ago  | hide | 39 comments
#
#
#       16.      The Delicious Origins of the Domesticated Blueberry (2016) (jstor.org)
#         22 points by nkurz 5 hours ago  | hide | 15 comments
#
#
#       17.      GraphQL JIT – GraphQL execution using a JIT compiler (github.com/zalando-incubator)
#         12 points by cheeseface 2 hours ago  | hide | discuss
#
#
#       18.      My real life use-case for generics in Go: API for client-side pagination (vladimir.varank.in)
#         18 points by varankinv 3 hours ago  | hide | 9 comments
#
#
#       19.      Missing TLS intermediate certificates can create mysterious browser problems (utoronto.ca)
#         51 points by zdw 7 hours ago  | hide | 28 comments
#
#
#       20.      AI and Machine Learning – The Basics (steveblank.com)
#         144 points by sblank 12 hours ago  | hide | 34 comments
#
#
#       21.      Rust: A Critical Retrospective (bunniestudios.com)
#         4 points by sohkamyung 1 hour ago  | hide | discuss
#
#
#       22.      Does communication matter in technical interviews? Here's the data (interviewing.io)
#         50 points by leeny 7 hours ago  | hide | 26 comments
#
#
#       23.      How to make video calls almost as good as face-to-face (2020) (benkuhn.net)
#         112 points by outworlder 13 hours ago  | hide | 80 comments
#
#
#       24.      Owl: OCaml Scientific Computing (ocaml.xyz)
#         60 points by lnyan 9 hours ago  | hide | 10 comments
#
#
#       25.      Apple Is Union-Busting in NYC, Labor Group Alleges (bloomberg.com)
#         17 points by carlycue 1 hour ago  | hide | discuss
#
#
#       26.      Long-Term Building in Japan (longnow.org)
#         109 points by tosh 13 hours ago  | hide | 89 comments
#
#
#       27.      Steps towards debugging and resolving Android bootloops (truschnigg.info)
#         11 points by c0l0 3 hours ago  | hide | 1 comment
#
#
#       28.      Billing systems are a nightmare for engineers (getlago.com)
#         691 points by Rafsark 19 hours ago  | hide | 334 comments
#
#
#       29.      Software Engineering Insights from 10 Years at Google (addyosmani.com)
#         122 points by feross 12 hours ago  | hide | 94 comments
#
#
#       30.      .NET 7 introduces Native AOT (microsoft.com)
#         86 points by DeathArrow 5 hours ago  | hide | 60 comments
#
#
#       More
#
#
# Guidelines
#         | FAQ
#         | Lists
#         | API
#         | Security
#         | Legal
#         | Apply to YC
#         | ContactSearch:

# %%
# Find all articles
summaries = soup.find_all("tr", class_="athing")
summaries[1]
# Out:
# <tr class="athing" id="31426683">
#       <td align="right" class="title" valign="top"><span class="rank">2.</span></td>      <td class="votelinks" valign="top"><center><a href="vote?id=31426683&amp;how=up&amp;goto=news" id="up_31426683"><div class="votearrow" title="upvote"></div></a></center></td><td class="title"><a class="titlelink" href="https://tarunreddy.bearblog.dev/addict/">I'm an addict</a><span class="sitebit comhead"> (<a href="from?site=bearblog.dev"><span class="sitestr">bearblog.dev</span></a>)</span></td></tr>

# %%
# Extract title
summaries[0].find("a", class_="titlelink").get_text().strip()
# Out:
# 'Outhorse Your Email'

# %%
# Find all articles, extract titles
articles=[]
summaries=soup.find_all("tr", class_="athing")
for summary in summaries:
  title =summary.find("a",class_='titlelink').get_text().strip()
  articles.append((title))

print(len(articles), "Article summaries found. Sample:")
print(articles[0])
# Out:
# 30 Article summaries found. Sample:
# Outhorse Your Email

# %% [markdown]
# #### Normalization
# ##### Case Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
# Convert to lowercase
text = text.lower() 
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %% [markdown]
# ##### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text) 
print(text)
# Out:
# the first time you see the second renaissance it may look boring  look at it at least twice and definitely watch part 2  it will change your view of the matrix  are the human people the ones who started the war   is ai a bad thing

# %% [markdown]
# #### Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %% [markdown]
# #### NLTK: Natural Language ToolKit

# %%
from nltk.tokenize import word_tokenize
